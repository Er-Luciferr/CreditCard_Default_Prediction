# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv('creditCardFraud_28011964_120214.csv')
data.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0      9000       689       679                           0
# 1      1000      1000       800                           0
# 2     20239     13750     13770                           0
# 3       581      1687      1542                           0
# 4      1000      1000      1000                           0
#
# [5 rows x 24 columns]

# %%
# !pip install ydata-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ydata-profiling in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (4.6.5)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (1.11.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (2.2.1)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (3.7.2)
# Requirement already satisfied: pydantic>=2 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (2.6.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (3.1.2)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (0.7.5)
# Requirement already satisfied: numpy<1.26,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (1.24.3)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (4.65.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (1.11.2)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (0.14.1)
# Requirement already satisfied: typeguard<5,>=4.1.2 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (4.1.5)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from ydata-profiling) (1.8.1)
# Requirement already satisfied: numba<0.59.0,>=0.56.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling) (0.57.1)
# Requirement already satisfied: PyWavelets in c:\programdata\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.4.1)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (9.4.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\programdata\anaconda3\lib\site-packages (from numba<0.59.0,>=0.56.0->ydata-profiling) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from pydantic>=2->ydata-profiling) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\er_luciferr.luc.000\appdata\roaming\python\python311\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5.4->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(data , title= 'CreditReport')
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
data.shape
# Out:
# (1001, 24)

# %%
data.isna().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
#  13  BILL_AMT3                   1001 non-null   int64
#  14  BILL_AMT4                   1001 non-null   int64
#  15  BILL_AMT5                   1001 non-null   int64
#  16  BILL_AMT6                   1001 non-null   int64
#  17  PAY_AMT1                    1001 non-null   int64
#  18  PAY_AMT2                    1001 non-null   int64
#  19  PAY_AMT3                    1001 non-null   int64
#  20  PAY_AMT4                    1001 non-null   int64
#  21  PAY_AMT5                    1001 non-null   int64
#  22  PAY_AMT6                    1001 non-null   int64
#  23  default payment next month  1001 non-null   int64
# dtypes: int64(24)
# memory usage: 187.8 KB

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(13,8))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# From the correlation heatmap above, it can be seen that there are some relationships between the feature columns, they are not entirely independent.
#
# But in this scenario, there is a correlation because a customer who was not able to pay the bill for 1 month was again not able to pay it for the subsequent months and hence the correlation.
#
# Again for the bill amount column, the same has happened. If the customer was not able to pay the bill, then the bill amount almost remained the same, or if the customer was able to pay then the bill amount got reduced.
#
# We remove columns when they convey the same information. But here, dropping the columns shall result in the loss of bill and payment history data. So, we don’t need to drop any column although there is a correlation.

# %% [markdown]
# # Spliting dependent and independent of features

# %%
X = data.drop(labels=['default payment next month'], axis=1)
y= data['default payment next month']

# %%
X.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],
#       dtype='object')

# %%
X.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0      0  ...      35835      20940      19146      19131      2000     36681
# 1      0  ...      57608      19394      19619      20024      2500      1815
# 2      0  ...     445007     542653     483003     473944     55000     40000
# 3      0  ...        601        221       -159        567       380       601
# 4      0  ...      12108      12211      11793       3719      3329         0
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0     10000      9000       689       679
# 1       657      1000      1000       800
# 2     38000     20239     13750     13770
# 3         0       581      1687      1542
# 4       432      1000      1000      1000
#
# [5 rows x 23 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: default payment next month, dtype: int64

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33 , random_state=42)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_train_data = scaler.fit_transform(X_train)
scaled_test_data = scaler.transform(X_test)

# %%
type(scaled_train_data) , type(X)
# Out:
# (numpy.ndarray, pandas.core.frame.DataFrame)

# %% [markdown]
# # Model Training
#
# Gaussian Naive Baye's

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
def metrics(y_true , y_predicted):
    ac=accuracy_score(y_true,y_predicted)
    cm=confusion_matrix(y_true,y_predicted)
    cr=classification_report(y_true,y_predicted)
    return print("Accuracy_score is:-  {0} \n----------------------------------\n Confusion_matrix is:- \n {1} \n-----------------------------------\n Classification_report is:-\n {2}".format(ac,cm,cr))

def get_difference(y_true , y_predicted , y_predicted_cv):
    as1 = accuracy_score(y_true , y_predicted_cv)
    as2 = accuracy_score(y_true , y_predicted)
    diff= as1-as2 
    return print("Model is performing:- {:.2f} % better \n Without CV accuracy:- {:.2f} % \n After CV accuracy:- {:.2f} %".format(diff*100,as2*100 ,as1*100 ))
    #return diff

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
y_pred=gnb.fit(scaled_train_data,y_train).predict(scaled_test_data)
metrics(y_test , y_pred)
# Out:
# Accuracy_score is:-  0.676737160120846
# ----------------------------------
#  Confusion_matrix is:-
#  [[188  83]
#  [ 24  36]]
# -----------------------------------
#  Classification_report is:-
#                precision    recall  f1-score   support
#
#            0       0.89      0.69      0.78       271
#            1       0.30      0.60      0.40        60
#
#     accuracy                           0.68       331
#    macro avg       0.59      0.65      0.59       331
# weighted avg       0.78      0.68      0.71       331

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
y_pred1=rf.fit(scaled_train_data,y_train).predict(scaled_test_data)
metrics(y_test , y_pred1)
# Out:
# Accuracy_score is:-  0.8368580060422961
# ----------------------------------
#  Confusion_matrix is:-
#  [[264   7]
#  [ 47  13]]
# -----------------------------------
#  Classification_report is:-
#                precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91       271
#            1       0.65      0.22      0.33        60
#
#     accuracy                           0.84       331
#    macro avg       0.75      0.60      0.62       331
# weighted avg       0.81      0.84      0.80       331

# %% [markdown]
# XG Boost Classifier

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
y_pred2 = xgb.fit(scaled_train_data,y_train).predict(scaled_test_data)
metrics(y_test , y_pred2)
# Out:
# Accuracy_score is:-  0.8126888217522659
# ----------------------------------
#  Confusion_matrix is:-
#  [[248  23]
#  [ 39  21]]
# -----------------------------------
#  Classification_report is:-
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89       271
#            1       0.48      0.35      0.40        60
#
#     accuracy                           0.81       331
#    macro avg       0.67      0.63      0.65       331
# weighted avg       0.79      0.81      0.80       331

# %% [markdown]
# # Model Evaluation
# <h3>Hyperparameter Tuning

# %% [markdown]
# 1) Gaussian Naive Baye's

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'var_smoothing':[ 1e-12,1e-10,1e-6,1e-4,1e-3,1e-2,1e-1,0.1,0.001,0.5,0.005]}
grid=GridSearchCV(estimator=gnb,param_grid=param_grid,cv=5,verbose=3)
grid.fit(scaled_train_data,y_train)
grid.best_params_
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [CV 1/5] END ...............var_smoothing=1e-12;, score=0.299 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-12;, score=0.769 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-12;, score=0.694 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-12;, score=0.679 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-12;, score=0.679 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-10;, score=0.299 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-10;, score=0.769 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-10;, score=0.694 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-10;, score=0.679 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-10;, score=0.679 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-06;, score=0.299 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-06;, score=0.769 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-06;, score=0.694 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-06;, score=0.679 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-06;, score=0.679 total time=   0.0s
# [CV 1/5] END ..............var_smoothing=0.0001;, score=0.299 total time=   0.0s
# [CV 2/5] END ..............var_smoothing=0.0001;, score=0.769 total time=   0.0s
# [CV 3/5] END ..............var_smoothing=0.0001;, score=0.694 total time=   0.0s
# [CV 4/5] END ..............var_smoothing=0.0001;, score=0.679 total time=   0.0s
# [CV 5/5] END ..............var_smoothing=0.0001;, score=0.679 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=0.001;, score=0.299 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=0.001;, score=0.769 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=0.001;, score=0.694 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=0.001;, score=0.679 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=0.001;, score=0.679 total time=   0.0s
# [CV 1/5] END ................var_smoothing=0.01;, score=0.306 total time=   0.0s
# [CV 2/5] END ................var_smoothing=0.01;, score=0.784 total time=   0.0s
# [CV 3/5] END ................var_smoothing=0.01;, score=0.694 total time=   0.0s
# [CV 4/5] END ................var_smoothing=0.01;, score=0.679 total time=   0.0s
# [CV 5/5] END ................var_smoothing=0.01;, score=0.679 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.1;, score=0.321 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.1;, score=0.776 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.1;, score=0.731 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.1;, score=0.679 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.1;, score=0.724 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.1;, score=0.321 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.1;, score=0.776 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.1;, score=0.731 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.1;, score=0.679 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.1;, score=0.724 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=0.001;, score=0.299 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=0.001;, score=0.769 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=0.001;, score=0.694 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=0.001;, score=0.679 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=0.001;, score=0.679 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.5;, score=0.746 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.5;, score=0.784 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.5;, score=0.799 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.5;, score=0.731 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.5;, score=0.776 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=0.005;, score=0.299 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=0.005;, score=0.784 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=0.005;, score=0.694 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=0.005;, score=0.679 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=0.005;, score=0.679 total time=   0.0s
# {'var_smoothing': 0.5}

# %%
gnb_cv = GaussianNB(var_smoothing=0.5)
y_pred_cv=gnb_cv.fit(scaled_train_data,y_train).predict(scaled_test_data)
metrics(y_test , y_pred_cv)
# Out:
# Accuracy_score is:-  0.8066465256797583
# ----------------------------------
#  Confusion_matrix is:-
#  [[243  28]
#  [ 36  24]]
# -----------------------------------
#  Classification_report is:-
#                precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       271
#            1       0.46      0.40      0.43        60
#
#     accuracy                           0.81       331
#    macro avg       0.67      0.65      0.66       331
# weighted avg       0.80      0.81      0.80       331

# %%
get_difference(y_test , y_pred , y_pred_cv)
# Out:
# Model is performing:- 12.99 % better
#  Without CV accuracy:- 67.67 %
#  After CV accuracy:- 80.66 %

# %% [markdown]
# 2) Random Forest Classifier

# %%
param_grid1= {"n_estimators":[100,50,150], "criterion":['gini','entropy','log_loss'], 'max_depth':[1,3,9,15],'max_features':['sqrt','log2'],'oob_score':[True,False], 'class_weight':['balanced','balanced_subsample'],'random_state':[0,50,42] }
grid=GridSearchCV(estimator=rf,param_grid=param_grid1,cv=5,verbose=3)
grid.fit(scaled_train_data,y_train)
grid.best_params_
# Out:
# Fitting 5 folds for each of 864 candidates, totalling 4320 fits
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=0;, score=0.799 total time=   0.4s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=0;, score=0.746 total time=   0.6s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=0;, score=0.731 total time=   0.6s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=0;, score=0.746 total time=   0.8s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=0;, score=0.687 total time=   0.4s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=50;, score=0.784 total time=   0.4s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=50;, score=0.761 total time=   0.4s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=50;, score=0.687 total time=   0.4s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=50;, score=0.709 total time=   0.4s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=50;, score=0.679 total time=   0.4s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=42;, score=0.799 total time=   0.6s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=42;, score=0.769 total time=   0.5s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=42;, score=0.716 total time=   0.8s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=42;, score=0.746 total time=   0.4s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=True, random_state=42;, score=0.672 total time=   0.4s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=0;, score=0.799 total time=   0.4s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=0;, score=0.746 total time=   0.4s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=0;, score=0.731 total time=   0.3s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=0;, score=0.746 total time=   0.4s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=0;, score=0.687 total time=   0.5s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=50;, score=0.784 total time=   0.5s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=50;, score=0.761 total time=   0.5s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=50;, score=0.687 total time=   0.4s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=50;, score=0.709 total time=   0.5s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=50;, score=0.679 total time=   0.5s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=42;, score=0.799 total time=   0.5s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=42;, score=0.769 total time=   0.4s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=42;, score=0.716 total time=   0.3s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=42;, score=0.746 total time=   0.3s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100, oob_score=False, random_state=42;, score=0.672 total time=   0.3s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=0;, score=0.806 total time=   0.1s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=0;, score=0.739 total time=   0.1s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=0;, score=0.739 total time=   0.1s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=0;, score=0.739 total time=   0.1s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=0;, score=0.664 total time=   0.1s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=50;, score=0.791 total time=   0.2s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=50;, score=0.776 total time=   0.1s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=50;, score=0.701 total time=   0.2s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=50;, score=0.739 total time=   0.1s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=50;, score=0.672 total time=   0.1s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=42;, score=0.776 total time=   0.1s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=42;, score=0.761 total time=   0.2s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=42;, score=0.701 total time=   0.1s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=42;, score=0.724 total time=   0.2s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=True, random_state=42;, score=0.649 total time=   0.1s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=0;, score=0.806 total time=   0.1s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=0;, score=0.739 total time=   0.1s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=0;, score=0.739 total time=   0.1s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=0;, score=0.739 total time=   0.1s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=0;, score=0.664 total time=   0.1s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=50;, score=0.791 total time=   0.1s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=50;, score=0.776 total time=   0.1s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=50;, score=0.701 total time=   0.1s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=50;, score=0.739 total time=   0.1s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=50;, score=0.672 total time=   0.1s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=42;, score=0.776 total time=   0.1s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=42;, score=0.761 total time=   0.1s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=42;, score=0.701 total time=   0.1s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=42;, score=0.724 total time=   0.1s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=50, oob_score=False, random_state=42;, score=0.649 total time=   0.1s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=0;, score=0.806 total time=   0.6s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=0;, score=0.746 total time=   0.6s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=0;, score=0.731 total time=   0.6s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=0;, score=0.761 total time=   0.6s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=0;, score=0.694 total time=   0.6s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=50;, score=0.799 total time=   0.6s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=50;, score=0.754 total time=   0.7s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=50;, score=0.701 total time=   0.8s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=50;, score=0.746 total time=   0.8s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=50;, score=0.694 total time=   0.8s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=42;, score=0.813 total time=   0.7s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=42;, score=0.769 total time=   0.5s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=42;, score=0.731 total time=   0.6s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=42;, score=0.746 total time=   0.6s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=True, random_state=42;, score=0.709 total time=   0.7s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=False, random_state=0;, score=0.806 total time=   0.5s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=False, random_state=0;, score=0.746 total time=   0.4s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=False, random_state=0;, score=0.731 total time=   0.5s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=False, random_state=0;, score=0.761 total time=   0.5s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=False, random_state=0;, score=0.694 total time=   0.4s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=False, random_state=50;, score=0.799 total time=   0.6s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=False, random_state=50;, score=0.754 total time=   0.5s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_depth=1, max_features=sqrt, n_estimators=150, oob_score=False, random_state
3s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=0;, score=0.761 total time=   0.3s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=0;, score=0.784 total time=   0.3s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=0;, score=0.754 total time=   0.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=50;, score=0.746 total time=   0.2s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=50;, score=0.784 total time=   0.3s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=50;, score=0.761 total time=   0.2s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=50;, score=0.761 total time=   0.4s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=50;, score=0.709 total time=   0.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=42;, score=0.761 total time=   0.2s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=42;, score=0.776 total time=   0.2s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=42;, score=0.746 total time=   0.3s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=42;, score=0.769 total time=   0.2s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=True, random_state=42;, score=0.746 total time=   0.3s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=0;, score=0.754 total time=   0.3s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=0;, score=0.776 total time=   0.2s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=0;, score=0.761 total time=   0.3s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=0;, score=0.784 total time=   0.3s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=0;, score=0.754 total time=   0.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=50;, score=0.746 total time=   0.2s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=50;, score=0.784 total time=   0.3s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=50;, score=0.761 total time=   0.2s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=50;, score=0.761 total time=   0.2s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=50;, score=0.709 total time=   0.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=42;, score=0.761 total time=   0.2s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=42;, score=0.776 total time=   0.3s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=42;, score=0.746 total time=   0.2s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=42;, score=0.769 total time=   0.2s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=50, oob_score=False, random_state=42;, score=0.746 total time=   0.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=0;, score=0.776 total time=   0.9s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=0;, score=0.776 total time=   0.9s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=0;, score=0.769 total time=   0.9s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=0;, score=0.769 total time=   0.9s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=0;, score=0.754 total time=   0.9s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=50;, score=0.769 total time=   0.9s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=50;, score=0.776 total time=   0.9s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=50;, score=0.754 total time=   0.9s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=50;, score=0.746 total time=   0.9s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=50;, score=0.739 total time=   0.9s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=42;, score=0.769 total time=   0.9s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=42;, score=0.784 total time=   0.9s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=42;, score=0.761 total time=   0.9s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=42;, score=0.776 total time=   0.9s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=True, random_state=42;, score=0.739 total time=   1.0s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=0;, score=0.776 total time=   0.8s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=0;, score=0.776 total time=   0.8s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=0;, score=0.769 total time=   0.9s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=0;, score=0.769 total time=   0.8s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=0;, score=0.754 total time=   0.8s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=50;, score=0.769 total time=   0.8s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=50;, score=0.776 total time=   0.9s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=50;, score=0.754 total time=   0.8s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=50;, score=0.746 total time=   0.8s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=50;, score=0.739 total time=   0.8s
# [CV 1/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=42;, score=0.769 total time=   0.8s
# [CV 2/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=42;, score=0.784 total time=   0.8s
# [CV 3/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=42;, score=0.761 total time=   0.9s
# [CV 4/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=42;, score=0.776 total time=   0.8s
# [CV 5/5] END class_weight=balanced_subsample, criterion=log_loss, max_depth=15, max_features=log2, n_estimators=150, oob_score=False, random_state=42;, score=0.739 total time=   0.9s
# {'class_weight': 'balanced_subsample',
#  'criterion': 'gini',
#  'max_depth': 9,
#  'max_features': 'sqrt',
#  'n_estimators': 50,
#  'oob_score': True,
#  'random_state': 42}

# %% [markdown]
# {'class_weight': 'balanced_subsample',
#  'criterion': 'gini',
#  'max_depth': 9,
#  'max_features': 'sqrt',
#  'n_estimators': 50,
#  'oob_score': True,
#  'random_state': 42}

# %%
rf_cv1_1 = RandomForestClassifier(class_weight='balanced_subsample', criterion='gini', max_depth= 9,max_features= 'sqrt',n_estimators=100,oob_score=True,random_state=0)
y_pred_cv1_1=rf_cv1_1.fit(scaled_train_data,y_train).predict(scaled_test_data)
metrics(y_test , y_pred_cv1_1)
# Out:
# Accuracy_score is:-  0.8398791540785498
# ----------------------------------
#  Confusion_matrix is:-
#  [[258  13]
#  [ 40  20]]
# -----------------------------------
#  Classification_report is:-
#                precision    recall  f1-score   support
#
#            0       0.87      0.95      0.
total time=   0.1s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=30;, score=0.761 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=30;, score=0.769 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=30;, score=0.776 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=30;, score=0.769 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=30;, score=0.731 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=33;, score=0.761 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=33;, score=0.776 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=33;, score=0.754 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=33;, score=0.776 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=33;, score=0.739 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=36;, score=0.784 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=36;, score=0.769 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=36;, score=0.754 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=36;, score=0.761 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=36;, score=0.731 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=39;, score=0.769 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=39;, score=0.769 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=39;, score=0.754 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=39;, score=0.746 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=50, oob_score=True, random_state=39;, score=0.761 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=0;, score=0.761 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=0;, score=0.761 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=0;, score=0.776 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=0;, score=0.746 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=0;, score=0.761 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=3;, score=0.776 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=3;, score=0.784 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=3;, score=0.754 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=3;, score=0.791 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=3;, score=0.761 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=6;, score=0.769 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=6;, score=0.784 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=6;, score=0.724 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=6;, score=0.769 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=6;, score=0.739 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=9;, score=0.784 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=9;, score=0.746 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=9;, score=0.806 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=9;, score=0.784 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=9;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=12;, score=0.769 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=12;, score=0.769 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=12;, score=0.791 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=12;, score=0.784 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=12;, score=0.739 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=15;, score=0.769 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=15;, score=0.776 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=15;, score=0.754 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=15;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=15;, score=0.746 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=18;, score=0.769 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=18;, score=0.791 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=18;, score=0.761 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=18;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=18;, score=0.761 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=21;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=21;, score=0.784 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=21;, score=0.739 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=21;, score=0.761 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=21;, score=0.731 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=24;, score=0.776 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=24;, score=0.799 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=24;, score=0.769 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=24;, score=0.769 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=24;, score=0.724 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=27;, score=0.776 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=27;, score=0.761 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=27;, score=0.769 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=27;, score=0.784 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=27;, score=0.769 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=30;, score=0.769 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=30;, score=0.784 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=30;, score=0.761 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=30;, score=0.791 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=30;, score=0.731 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=33;, score=0.761 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=33;, score=0.776 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=33;, score=0.769 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=33;, score=0.776 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=33;, score=0.746 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=36;, score=0.769 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=36;, score=0.784 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=36;, score=0.769 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=36;, score=0.776 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=36;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=39;, score=0.769 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=39;, score=0.799 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=39;, score=0.754 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=39;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=75, oob_score=True, random_state=39;, score=0.746 total time=   0.2s
# {'criterion': 'entropy',
#  'max_features': 'sqrt',
#  'n_estimators': 50,
#  'oob_score': True,
#  'random_state': 12}

# %%
rf_cv = RandomForestClassifier(class_weight='balanced_subsample', criterion='entropy', max_depth= 9,max_features= 'sqrt',n_estimators=50,oob_score=True,random_state=0)
y_pred_cv1=rf_cv.fit(scaled_train_data,y_train).predict(scaled_test_data)
metrics(y_test , y_pred_cv1)
# Out:
# Accuracy_score is:-  0.8549848942598187
# ----------------------------------
#  Confusion_matrix is:-
#  [[260  11]
#  [ 37  23]]
# -----------------------------------
#  Classification_report is:-
#                precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       271
#            1       0.68      0.38      0.49        60
#
#     accuracy                           0.85       331
#    macro avg       0.78      0.67      0.70       331
# weighted avg       0.84      0.85      0.84       331

# %%
get_difference(y_test , y_pred1 , y_pred_cv1)
# Out:
# Model is performing:- 1.81 % better
#  Without CV accuracy:- 83.69 %
#  After CV accuracy:- 85.50 %

# %% [markdown]
# 3) XG Boost Classifier

# %%
param_grid_xgboost = {"n_estimators": [50,100, 130],"max_depth": range(3, 11, 1),"random_state":[0,50,100]}
